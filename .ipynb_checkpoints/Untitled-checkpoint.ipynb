# %%
# %matplotlib inline
import os
os.environ['USE_PYGEOS'] = '0'
import geopandas as gpd
import pandas as pd
import pysal
from collections import defaultdict
import matplotlib.pyplot as plt
import matplotlib as mpl
from matplotlib.pylab import cm

from shapely.geometry import Point

from esda.getisord import G_Local
from esda.moran import Moran
from libpysal.weights import KNN

from tqdm.auto import tqdm
import random
import mapclassify

# %%
# !pip install pysal

# %%
detroitCrime=pd.read_csv('Detroit-RMS_Crime_Incidents.csv')
# Out:
# C:\Users\risha\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3444: DtypeWarning: Columns (8,15,16) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
detroitCrime
# Out:
#                 X          Y  crime_id  report_number  \
# 0      -83.163011  42.427745   3535020     2008170095
# 1      -83.131659  42.307950   3006180     1612260018
# 2      -83.204470  42.439354   3018963     1701280234
# 3      -83.018830  42.355350   3019773     1701310083
# 4      -82.996568  42.368237   3021816     1702060055
# ...           ...        ...       ...            ...
# 499061 -83.175316  42.427572   3858662     2301250085
# 499062 -83.233852  42.335888   3858669     2301250127
# 499063 -83.029858  42.438757   3858705     2301250161
# 499064 -83.002796  42.397527   3858707     2301250135
# 499065 -83.117377  42.407905   3858736     2301250189
#
#                           address  \
# 0         Margareta St & Ilene St
# 1        Lawndale St & Senator St
# 2           Prevost St & Fargo St
# 3       Burlage Pl & Hendricks St
# 4           Goethe Ave & Crane St
# ...                           ...
# 499061  W Outer Dr & Margareta St
# 499062    Plainview Ave & Paul Dr
# 499063      Rogge St & E Lantz St
# 499064     Marcus Ave & Kresge St
# 499065      Idaho St & Pilgrim St
#
#                                       offense_description    offense_category  \
# 0                                                   ARSON               ARSON
# 1                                                   ARSON               ARSON
# 2                                         LARCENY - OTHER             LARCENY
# 3                                         LARCENY - OTHER             LARCENY
# 4                                                 ROBBERY             ROBBERY
# ...                                                   ...                 ...
# 499061                            BURGLARY - FORCED ENTRY            BURGLARY
# 499062  MOTOR VEHICLE AS STOLEN PROPERTY (RECOVERED ONLY)     STOLEN PROPERTY
# 499063                                    LARCENY - OTHER             LARCENY
# 499064                               RETAIL FRAUD - THEFT               FRAUD
# 499065                                 DAMAGE TO PROPERTY  DAMAGE TO PROPERTY
#
#         state_offense_code arrest_charge  \
# 0                     2099         20000
# 1                     2099         20000
# 2                     2307         23007
# 3                     2307         23007
# 4                     1201         12000
# ...                    ...           ...
# 499061                2201         22001
# 499062                2402         24002
# 499063                2307         23007
# 499064                3072         30002
# 499065                2900         29000
#
#                                        charge_description  ... scout_car_area  \
# 0                                                   ARSON  ...           1207
# 1                                                   ARSON  ...           0408
# 2                                         LARCENY - OTHER  ...           0804
# 3                                         LARCENY - OTHER  ...           0707
# 4                                                 ROBBERY  ...           0708
# ...                                                   ...  ...            ...
# 499061                            BURGLARY - FORCED ENTRY  ...           1207
# 499062  MOTOR VEHICLE AS STOLEN PROPERTY (RECOVERED ONLY)  ...            612
# 499063                                    LARCENY - OTHER  ...           1104
# 499064                               RETAIL FRAUD - THEFT  ...            501
# 499065                                 DAMAGE TO PROPERTY  ...           1212
#
#        precinct         block_id     neighborhood  council_district zip_code  \
# 0            12  261635387003006          Schulze                 2    48221
# 1            04  261635242005002      Springwells                 6    48209
# 2            08  261635401002003       Greenfield                 2    48235
# 3            07  261635168001006   McDougall-Hunt                 5    48207
# 4            07  261635156002003     East Village                 5    48214
# ...         ...              ...              ...               ...      ...
# 499061       12  261635394003024          Schulze                 2    48235
# 499062        6  261635458003004       Warrendale                 7    48228
# 499063       11  261635062002011          Nortown                 3    48234
# 499064        5  261635055001038      Airport Sub                 3    48213
# 499065       12  261635301002001  Pilgrim Village                 2    48238
#
#         longitude   latitude                ibr_date     oid
# 0      -83.163011  42.427745  2020/08/20 16:52:43+00       1
# 1      -83.131659  42.307950  2017/05/29 15:26:32+00       2
# 2      -83.204470  42.439354  2017/02/22 15:33:09+00       3
# 3      -83.018830  42.355350  2017/02/22 15:33:09+00       4
# 4      -82.996568  42.368237  2017/05/15 12:48:09+00       5
# ...           ...        ...                     ...     ...
# 499061 -83.175316  42.427572                     NaN  499062
# 499062 -83.233852  42.335888                     NaN  499063
# 499063 -83.029858  42.438757                     NaN  499064
# 499064 -83.002796  42.397527                     NaN  499065
# 499065 -83.117377  42.407905                     NaN  499066
#
# [499066 rows x 25 columns]
